# %% [raw]
# # Python Systems process and automation with python
#
# ### Goal:
#
# Every day our system will update sales from the day before.
# Our everyday work as an analyst is to email the board of directors at the start of the day with revenue and amount of sales from the prior work day
#
# Board E-mail: seugmail+diretoria@gmail.com<br>
# Sales file location: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing

# %%
# !pip install pyautogui
# Out:
# ...
# [notice] A new release of pip is available: 23.1.1 -> 25.1.1
# [notice] To update, run: C:\Users\xandi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install pyautogui
#pyautogui.click - click mouse
#pyautogui.write - write text
#pyautogui.press - press button
#pyautogui.hotkey - any hotkay use
# Out:
# ...
#   Using cached PyAutoGUI-0.9.54.tar.gz (61 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached pytweening-1.2.0.tar.gz (171 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pyscreeze-1.0.1.tar.gz (27 kB)
# ...

# %%
import pyautogui
import pyperclip
import time

pyautogui.pause = 1
# Step 1 go inside company system (google drive link in this case)
#opening browser
#pyautogui.press("iniciar")
#pyautogui.write("edge")
#pyautogui.press("enter")
#pyautogui.press("microsoft edge")
#or open new tab after browser is already open
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

#step 1 complete
#site loading.. 
time.sleep(5) # this step is used because of the loading time of websites, depending on the local internet conection it could be slower or faster, but awlays take some time

# step 2 browse in system to the database 
pyautogui.doubleClick(x=2295, y=336) #.click demands pixels position 
#or pyautogui.click(x=2295, y=336, clicks=2)
time.sleep(3)#to wait for the webpage to load


# step 3 download of the database
pyautogui.click(x=2286, y=491)#file click
time.sleep(2)#little time to load the options menu after the first click
pyautogui.click(x=2560, y=224)#options click(tree vertical dots)
time.sleep(1)
pyautogui.click(x=2588, y=315)#download button pressing

time.sleep(7)# so we have time for the file to finish the download

# is important to know that screnn resolutions vary depending on the system, so we need to set the coordinates accordingly
# in case we need to scrool the screen, the command is pyautogui.scroll(x) x is a

# %% [markdown]
# ### Scan the downloaded file to get the following
#
# - invoicing
# - product amount

# %%
# step 4: indicators processing (invoicing, product quantities)
import pandas as pd

table = pd.read_excel(r"C:\Users\xandi\Downloads\Vendas - Dez.xlsx") # for python to locate the file we need to put the exact location 
display(table)# this python command is exclusive to jupyter
#we could use the print command but it would just be messy, but it also works
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
amount = table["Quantidade"].sum() #sum of column 'quantidade'(amount/quantity in portuguese). there are a number of 

revenue = table["Valor Final"].sum() # sum of column 'valor final'(final value in portuguese)

print(amount)
print(revenue)
# Out:
# 15227
# 2917311

# %%
#in case we are using other python intefaces 
#we need to install:
pandas
openpyxl
numpy
#jupyter have all this libraries

# %% [markdown]
# ### Sanding an email trought gmail

# %%
# step 5: entering email(gmail in this case)
pyautogui.hotkey("ctrl", "t") # open new tab
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox") # Email link copy
pyautogui.hotkey("ctrl", "v") # paste email link
pyautogui.press("enter") # entering site
time.sleep(7)
# passo 6 mandar email pra diretoria
# Click on the 'write' button
pyautogui.click(x=1991, y=181) #remember to use pyautogui.position()
time.sleep(2)
# write recipient email 
pyautogui.write("alexandrepbrauns@gmail.com") # choose and write recipient email. in our case is good to put our own email so we can see the result
pyautogui.press("tab") # tab select the appearing email
#write subject
pyautogui.press("tab") # pressing tab to chanche writing field
pyautogui.write("Sales Report")

#write email body
pyautogui.press("tab")

text = f"""Greetings, 
Yesterdey's revenue was :${revenue}, with an product sales on the amount of {amount}
regards,
Alex
"""
pyautogui.write(text)


#send email
pyautogui.click(x=3227, y=987)

# %% [markdown]
# #### This next code is to find in what position we click to select an item

# %%
#qtime.sleep(5) in case you need time to go to the browser and position the mouse on the button you need to know the coordinates
pyautogui.position()
# Out:
# Point(x=3227, y=987)
